# %%
import pandas as pd
import numpy as np
from pathlib import Path
from tensorflow.keras.layers import Dense , Flatten ,Embedding,Input,Concatenate,Flatten,Dropout,Activation,BatchNormalization
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping

# %%
def read_data(path):
    files = {}
    for filename in path.glob('*'):
        if filename.suffix == '.csv':
            files[filename.stem] = pd.read_csv(filename)
        elif filename.suffix == '.dat':
            if filename.stem == 'ratings':
                columns = ['userId', 'movieId', 'rating', 'timestamp']
            else:
                columns = ['movieId', 'title', 'genres']
            data = pd.read_csv(filename, sep='::', names=columns, engine='python')
            files[filename.stem] = data
    return files['ratings'], files['movies']

# %%
file_path=Path.cwd()/ 'ml-latest-small'
ratings, movies = read_data(file_path)

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
def matrix_preview(ratings, n=20):
    user_groups = ratings.groupby('userId')['rating'].count()
    top_users = user_groups.sort_values(ascending=False)[:n]
    movie_groups = ratings.groupby('movieId')['rating'].count()
    top_movies = movie_groups.sort_values(ascending=False)[:n]
    top = (
        ratings.
        join(top_users, rsuffix='_r', how='inner', on='userId').
        join(top_movies, rsuffix='_r', how='inner', on='movieId'))
    return pd.crosstab(top.userId, top.movieId, top.rating, aggfunc=np.sum)

# %%
matrix_preview(ratings,10)
# Out:
# movieId  1     260   296   318   356   480   527   589   593   2571
# userId
# 15        2.0   5.0   5.0   2.0   1.0   3.0   4.0   4.0   5.0   5.0
# 30        4.0   4.0   5.0   5.0   5.0   4.0   5.0   4.0   4.0   3.0
# 73        5.0   4.5   5.0   5.0   5.0   4.0   5.0   3.0   4.5   4.5
# 311       3.0   4.0   3.0   4.5   5.0   4.5   5.0   4.5   2.0   4.0
# 380       4.0   4.0   5.0   4.0   5.0   4.0   NaN   4.0   5.0   5.0
# 452       3.5   4.0   5.0   5.0   4.0   5.0   4.0   4.0   5.0   2.0
# 468       4.0   3.5   3.5   3.5   3.0   2.5   NaN   NaN   3.0   3.0
# 547       3.5   NaN   5.0   5.0   2.0   3.0   5.0   NaN   5.0   3.5
# 564       4.0   2.0   5.0   NaN   3.0   5.0   4.0   5.0   5.0   3.0
# 624       5.0   5.0   5.0   NaN   3.0   3.0   NaN   3.0   5.0   2.0

# %%
def create_dataset(ratings):  
    unique_users = ratings.userId.unique()
    user_to_index = {old: new for new, old in enumerate(unique_users)}
    new_users = ratings.userId.map(user_to_index)
    
    unique_movies = ratings.movieId.unique()
    movie_to_index = {old: new for new, old in enumerate(unique_movies)}
    new_movies = ratings.movieId.map(movie_to_index)
    
    n_users = unique_users.shape[0]
    n_movies = unique_movies.shape[0]
    
    X = pd.DataFrame({'user_id': new_users,'movie_id': new_movies})
    y = ratings['rating'].astype(np.float32)
    return (n_users, n_movies), (X, y), (user_to_index, movie_to_index)

# %%
(n_users, n_movies), (X, y), _ = create_dataset(ratings)

# %%
def gen_ncf(n_users,n_movies,n_factors=150,n_hidden=300):
    user_input=Input(shape=(1,)) 
    user_embedding=Embedding(n_users, n_factors, input_length=1)(user_input)
    user_embedding=Flatten()(user_embedding)
    movie_input=Input(shape=(1,)) 
    movie_embedding=Embedding(n_movies, n_factors, input_length=1)(movie_input)
    movie_embedding=Flatten()(movie_embedding)
    um_vector=Concatenate(axis=1)([user_embedding,movie_embedding])
    um_vector=Dense(n_hidden, use_bias=True)(um_vector)
 #   um_vector=BatchNormalization()(um_vector)
    um_vector=Activation("relu")(um_vector)
    um_vector=Dropout(0.25)(um_vector)
    um_vector=Dense(n_hidden,use_bias=True)(um_vector)
 #   um_vector=BatchNormalization()(um_vector)
    um_vector=Activation("relu")(um_vector)
    um_vector=Dropout(0.25)(um_vector)
    um_vector=Dense(n_hidden, activation='relu')(um_vector)
    um_vector=Dropout(0.25)(um_vector)
    output=Dense(1)(um_vector)
    model=Model([user_input,movie_input], output)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
ncf=gen_ncf(n_users,n_movies)
ncf.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 1, 150)       100650      input_5[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 1, 150)       1359900     input_6[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 150)          0           embedding_4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 150)          0           embedding_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 300)          0           flatten_4[0][0]
#                                                                  flatten_5[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 300)          90300       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 300)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 300)          0           activation_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 300)          90300       dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 300)          0           dense_9[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 300)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 300)          90300       dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 300)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            301         dropout_8[0][0]
# ==================================================================================================
# Total params: 1,731,751
# Trainable params: 1,731,751
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2)
datasets = {'train': (X_train, y_train), 'val': (X_valid, y_valid)}
dataset_sizes = {'train': len(X_train), 'val': len(X_valid)}

# %%
callback = EarlyStopping(monitor='val_loss', patience=3)

ncf.fit([X_train.user_id.values,X_train.movie_id.values], y_train.values,epochs=20,batch_size=2000,shuffle=True,
        callbacks=[callback],
        validation_data=(([X_valid.user_id.values,X_valid.movie_id.values],y_valid.values)))
# Out:
# Train on 80003 samples, validate on 20001 samples
# Epoch 1/20
# 80003/80003 [==============================] - 5s 67us/sample - loss: 3.5507 - val_loss: 0.9084
# Epoch 2/20
# 80003/80003 [==============================] - 4s 48us/sample - loss: 0.8904 - val_loss: 0.8104
# Epoch 3/20
# 80003/80003 [==============================] - 4s 49us/sample - loss: 0.8084 - val_loss: 0.8163
# Epoch 4/20
# 80003/80003 [==============================] - 4s 49us/sample - loss: 0.7583 - val_loss: 0.8027
# Epoch 5/20
# 80003/80003 [==============================] - 4s 52us/sample - loss: 0.7234 - val_loss: 0.8085
# Epoch 6/20
# 80003/80003 [==============================] - 4s 53us/sample - loss: 0.7082 - val_loss: 0.8091
# Epoch 7/20
# 80003/80003 [==============================] - 4s 52us/sample - loss: 0.6760 - val_loss: 0.8073

# %%
y_predict=ncf.predict([X_valid.user_id.values,X_valid.movie_id.values])

# %%
from sklearn.metrics import mean_squared_error
rmse=mean_squared_error(y_valid.values, y_predict)**0.5
print(rmse)
# Out:
# 0.8985120991129445
